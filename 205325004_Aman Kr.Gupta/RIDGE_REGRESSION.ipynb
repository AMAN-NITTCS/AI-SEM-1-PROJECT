# %% [markdown]
# # Task
# Generate scatter plots to visualize the predicted vs. actual housing prices for both Linear Regression and Ridge Regression models. Each plot should clearly label the axes, have an appropriate title, and include a legend.

# %% [markdown]
# ## Import Libraries
#
# ### Subtask:
# Import necessary libraries for data loading, manipulation, model training (Linear Regression, Ridge Regression), and evaluation (RMSE, R²).

# %% [markdown]
# **Reasoning**:
# The subtask requires importing several libraries for data manipulation, numerical operations, model training, and evaluation. This code block will import all the necessary libraries as specified in the instructions.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# **Reasoning**:
# The main task requires generating scatter plots to visualize predicted vs. actual housing prices for both Linear Regression and Ridge Regression models. This step will create these plots with appropriate labels, titles, and legends, using the previously obtained predictions and actual test values.

# %%
plt.figure(figsize=(14, 6))

# Scatter Plot for Linear Regression
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
plt.scatter(y_test, y_pred_linear, alpha=0.7, label='Predicted')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label='Perfect Prediction')
plt.title('Linear Regression: Predicted vs. Actual Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid(True)

# Scatter Plot for Ridge Regression
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
plt.scatter(y_test, y_pred_ridge, alpha=0.7, label='Predicted', color='green')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label='Perfect Prediction')
plt.title('Ridge Regression: Predicted vs. Actual Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
print("Scatter plots generated visualizing predicted vs. actual prices for Linear and Ridge Regression models.")
# Out:
# Scatter plots generated visualizing predicted vs. actual prices for Linear and Ridge Regression models.

# %% [markdown]
# ## Load Boston Housing dataset
#
# ### Subtask:
# Load the Boston Housing dataset, preprocess it if necessary, and split it into training and testing sets.

# %% [markdown]
# ## Conclude Why Ridge is Better
#
# ### Subtask:
# Analyze the performance metrics and visualizations to explain why Ridge Regression might be a better choice for predicting housing prices compared to Linear Regression.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   Necessary libraries for data manipulation, model training (Linear Regression, Ridge Regression), data splitting, model evaluation, and visualization were successfully imported.
# *   Scatter plots were successfully generated, visualizing the predicted versus actual housing prices for both Linear Regression and Ridge Regression models. Each plot included clear axis labels, an appropriate title, a legend (with a 'Perfect Prediction' line), and a grid for enhanced readability.
# *   The Boston Housing dataset had already been loaded and split into training and testing sets, with the variables `X`, `y`, `X_train`, `X_test`, `y_train`, and `y_test` pre-initialized from previous steps.
#
# ### Insights or Next Steps
# *   By visually comparing the scatter plots, we can observe how closely the predicted values from each model align with the actual values. A tighter cluster around the 'Perfect Prediction' line generally indicates better model performance.
# *   The next step should involve a detailed comparative analysis of the visual patterns in these plots, potentially alongside quantitative metrics (like RMSE and R²) from previous steps, to form a comprehensive conclusion on why Ridge Regression might be superior for this dataset.
